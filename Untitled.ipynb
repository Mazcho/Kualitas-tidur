# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\ASUS\anaconda3\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\Users\ASUS\anaconda3\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
df = pd.read_csv("ss.csv")
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 368        369  Female   59                 Nurse             8.1
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373 entries, 0 to 372
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                373 non-null    int64
#  1   Gender                   373 non-null    object
#  2   Age                      373 non-null    int64
#  3   Occupation               373 non-null    object
#  4   Sleep Duration           373 non-null    float64
#  5   Quality of Sleep         373 non-null    int64
#  6   Physical Activity Level  373 non-null    int64
#  7   Stress Level             373 non-null    int64
#  8   BMI Category             373 non-null    object
#  9   Blood Pressure           373 non-null    object
#  10  Heart Rate               373 non-null    int64
#  11  Daily Steps              373 non-null    int64
#  12  Sleep Disorder           373 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.0+ KB

# %%
df.isna().sum()
# Out:
# Person ID                  0
# Gender                     0
# Age                        0
# Occupation                 0
# Sleep Duration             0
# Quality of Sleep           0
# Physical Activity Level    0
# Stress Level               0
# BMI Category               0
# Blood Pressure             0
# Heart Rate                 0
# Daily Steps                0
# Sleep Disorder             0
# dtype: int64

# %%
# Membuat kolom baru untuk tekanan darah atas dan bawah
df["TOP Blood Preasure"] = 0
df["Bottom Blood Preasure"] = 0

# Memisahkan tekanan darah dan menambahkannya ke dalam kolom baru
for index, row in df.iterrows():
    top, bottom = row["Blood Pressure"].split("/")
    df.at[index, "TOP Blood Preasure"] = int(top)
    df.at[index, "Bottom Blood Preasure"] = int(bottom)

# %%
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 368        369  Female   59                 Nurse             8.1
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
df["Occupation"].value_counts()
# Out:
# Nurse                   72
# Doctor                  71
# Engineer                63
# Lawyer                  47
# Teacher                 40
# Accountant              37
# Salesperson             32
# Software Engineer        4
# Scientist                4
# Sales Representative     2
# Manager                  1
# Name: Occupation, dtype: int64

# %%
df["BMI Category"].value_counts()
# Out:
# Normal           195
# Overweight       147
# Normal Weight     21
# Obese             10
# Name: BMI Category, dtype: int64

# %%
df["Sleep Disorder"].value_counts()
# Out:
# None           219
# Sleep Apnea     77
# Insomnia        77
# Name: Sleep Disorder, dtype: int64

# %%
df["Gender"].value_counts()
# Out:
# Male      189
# Female    184
# Name: Gender, dtype: int64

# %%
columns = ["Occupation","BMI Category","Sleep Disorder","Gender"]
from sklearn.preprocessing import LabelEncoder
labeling = LabelEncoder()

for column in columns:
    df[column] = labeling.fit_transform(df[column])
    print(df[column])
# Out:
# 0      9
# 1      1
# 2      1
# 3      6
# 4      6
#       ..
# 368    5
# 369    5
# 370    5
# 371    5
# 372    5
# Name: Occupation, Length: 373, dtype: int32
# 0      3
# 1      0
# 2      0
# 3      2
# 4      2
#       ..
# 368    3
# 369    3
# 370    3
# 371    3
# 372    3
# Name: BMI Category, Length: 373, dtype: int32
# 0      1
# 1      1
# 2      1
# 3      2
# 4      2
#       ..
# 368    2
# 369    2
# 370    2
# 371    2
# 372    2
# Name: Sleep Disorder, Length: 373, dtype: int32
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 368    0
# 369    0
# 370    0
# 371    0
# 372    0
# Name: Gender, Length: 373, dtype: int32

# %%
df
# Out:
#      Person ID  Gender  Age  Occupation  Sleep Duration  Quality of Sleep  \
# 0            1       1   27           9             6.1                 6
# 1            2       1   28           1             6.2                 6
# 2            3       1   28           1             6.2                 6
# 3            4       1   28           6             5.9                 4
# 4            5       1   28           6             5.9                 4
# ..         ...     ...  ...         ...             ...               ...
# 368        369       0   59           5             8.1                 9
# 369        370       0   59           5             8.1                 9
# 370        371       0   59           5             8.0                 9
# 371        372       0   59           5             8.1                 9
# 372        373       0   59           5             8.1                 9
#
#      Physical Activity Level  Stress Level  BMI Category Blood Pressure  \
# ...

# %%
df["Occupation"].value_counts()
# Out:
# 5     72
# 1     71
# 2     63
# 3     47
# 10    40
# 0     37
# 7     32
# 9      4
# 8      4
# 6      2
# 4      1
# Name: Occupation, dtype: int64

# %%
df["Sleep Disorder"].value_counts()
# Out:
# 1    219
# 2     77
# 0     77
# Name: Sleep Disorder, dtype: int64

# %%
df["BMI Category"].value_counts()
# Out:
# 0    195
# 3    147
# 1     21
# 2     10
# Name: BMI Category, dtype: int64

# %%
df["Gender"].value_counts()
# Out:
# 1    189
# 0    184
# Name: Gender, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373 entries, 0 to 372
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                373 non-null    int64
#  1   Gender                   373 non-null    int32
#  2   Age                      373 non-null    int64
#  3   Occupation               373 non-null    int32
#  4   Sleep Duration           373 non-null    float64
#  5   Quality of Sleep         373 non-null    int64
#  6   Physical Activity Level  373 non-null    int64
#  7   Stress Level             373 non-null    int64
#  8   BMI Category             373 non-null    int32
#  9   Blood Pressure           373 non-null    object
#  10  Heart Rate               373 non-null    int64
#  11  Daily Steps              373 non-null    int64
#  12  Sleep Disorder           373 non-null    int32
#  13  TOP Blood Preasure       373 non-null    int64
# ...

# %%
df.drop("Blood Pressure",axis=1, inplace=True)

# %%
df.describe()
# Out:
#         Person ID      Gender         Age  Occupation  Sleep Duration  \
# count  373.000000  373.000000  373.000000  373.000000      373.000000
# mean   187.000000    0.506702   42.139410    3.769437        7.129491
# std    107.820066    0.500627    8.640793    3.059522        0.795139
# min      1.000000    0.000000   27.000000    0.000000        5.800000
# 25%     94.000000    0.000000   35.000000    1.000000        6.400000
# 50%    187.000000    1.000000   43.000000    3.000000        7.200000
# 75%    280.000000    1.000000   50.000000    5.000000        7.800000
# max    373.000000    1.000000   59.000000   10.000000        8.500000
#
#        Quality of Sleep  Physical Activity Level  Stress Level  BMI Category  \
# count        373.000000               373.000000    373.000000    373.000000
# mean           7.308311                59.128686      5.391421      1.292225
# std            1.195359                20.842589      1.772590      1.430418
# ...

# %%
df_regresi = df[df["Sleep Disorder"]==1]

# %%
df_regresi
# Out:
#      Person ID  Gender  Age  Occupation  Sleep Duration  Quality of Sleep  \
# 0            1       1   27           9             6.1                 6
# 1            2       1   28           1             6.2                 6
# 2            3       1   28           1             6.2                 6
# 7            8       1   29           1             7.8                 7
# 8            9       1   29           1             7.8                 7
# ..         ...     ...  ...         ...             ...               ...
# 341        342       0   56           1             8.2                 9
# 342        343       0   56           1             8.2                 9
# 343        344       0   57           5             8.1                 9
# 358        359       0   59           5             8.0                 9
# 359        360       0   59           5             8.1                 9
#
#      Physical Activity Level  Stress Level  BMI Category  Heart Rate  \
# ...

# %%
from sklearn.model_selection import train_test_split,KFold
from sklearn.metrics import r2_score,mean_squared_error, classification_report,f1_score

# %%
from sklearn.ensemble import GradientBoostingRegressor,GradientBoostingClassifier
from xgboost import XGBClassifier,XGBRegressor
from sklearn.ensemble import RandomForestRegressor,RandomForestClassifier
from sklearn.ensemble import AdaBoostRegressor,AdaBoostClassifier

# %%
model1 = GradientBoostingClassifier(random_state=42)
model2 = GradientBoostingRegressor(random_state=42)
model3 = XGBClassifier()
model4 = XGBRegressor()
model5 = RandomForestClassifier(random_state=42)
model6 = RandomForestRegressor(random_state=42)
model7 = AdaBoostRegressor(random_state=42)
model8 = AdaBoostClassifier(random_state=42)

# %% [markdown]
# # Regresi

# %%
X_duration = df_regresi[["Quality of Sleep","Stress Level","Physical Activity Level","BMI Category","Occupation"]] 
y_duration = df_regresi["Sleep Duration"]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_normalisasi = scaler.fit_transform(X_duration)

# %%
X_train2,X_test2,y_train2,y_test2 = train_test_split(X_normalisasi,y_duration,test_size=0.2,random_state=42)

# %%
model2.fit(X_train2,y_train2)
y_pred_duration = model2.predict(X_test2)

r2_score_duration_GBR = r2_score(y_test2,y_pred_duration)
rmse_GBR = np.sqrt(mean_squared_error(y_test2,y_pred_duration))

print(r2_score_duration_GBR)
print(rmse_GBR)
# Out:
# 0.9826755440692584
# 0.09141168937461931

# %%
model4.fit(X_train2,y_train2)
y_pred_duration = model4.predict(X_test2)

r2_score_duration_XGBR = r2_score(y_test2,y_pred_duration)
rmse_XGBR = np.sqrt(mean_squared_error(y_test2,y_pred_duration))

print(r2_score_duration_XGBR)
print(rmse_XGBR)
# Out:
# 0.9825233558061233
# 0.09181231861849136

# %%
model6.fit(X_train2,y_train2)
y_pred_duration = model6.predict(X_test2)

r2_score_duration_RF = r2_score(y_test2,y_pred_duration)
rmse_RF = np.sqrt(mean_squared_error(y_test2,y_pred_duration))

print(r2_score_duration_RF)
print(rmse_RF)
# Out:
# 0.9807985507774316
# 0.0962363043533465

# %%
model7.fit(X_train2,y_train2)
y_pred_duration = model7.predict(X_test2)

r2_score_duration_ADA = r2_score(y_test2,y_pred_duration)
rmse_ADA = np.sqrt(mean_squared_error(y_test2,y_pred_duration))

print(r2_score_duration_ADA)
print(rmse_ADA)
# Out:
# 0.9785790005102775
# 0.10164635235491679

# %%
inputan_user = [[9,3,75,3,5]]
hasil = model2.predict(inputan_user)
print(float(hasil))
# Out:
# 7.663531353119322

# %%
r2_score_hasil = pd.Series([r2_score_duration_GBR,r2_score_duration_RF,r2_score_duration_XGBR,r2_score_duration_ADA],index=["GBR","RF","XGBR","AdaBoost"])

# %%
rmse_hasil = pd.Series([rmse_GBR,rmse_RF,rmse_XGBR,rmse_ADA],index=["GBR","RF","XGBR","AdaBoost"])

# %%
data_metrics_regresi = pd.DataFrame([r2_score_hasil,rmse_hasil],index=["R2_Score","RMSE"])

# %%
data_metrics_regresi
# Out:
#                GBR        RF      XGBR  AdaBoost
# R2_Score  0.982676  0.980799  0.982523  0.978579
# RMSE      0.091412  0.096236  0.091812  0.101646

# %%
data_metrics_regresi = np.transpose(data_metrics_regresi)
data_metrics_regresi
# Out:
#           R2_Score      RMSE
# GBR       0.982676  0.091412
# RF        0.980799  0.096236
# XGBR      0.982523  0.091812
# AdaBoost  0.978579  0.101646

# %% [markdown]
# # Klasifikasi

# %%
X_sleep_disorder = df[["Quality of Sleep","Stress Level","Physical Activity Level","TOP Blood Preasure","Bottom Blood Preasure","Occupation"]] 
y_sleep_disorder = df["Sleep Disorder"]

# %%
from imblearn.over_sampling import SMOTE
balancing = SMOTE(k_neighbors=3)
X_resampled, y_resampled = balancing.fit_resample(X_sleep_disorder,y_sleep_disorder)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_normalisasi_klasifikasi = scaler.fit_transform(X_resampled)

# %%
X_train1,X_test1,y_train1,y_test1 = train_test_split(X_normalisasi_klasifikasi,y_resampled,test_size=0.2,random_state=42)

# %%
model1.fit(X_train1,y_train1)
y_pred_disorder = model1.predict(X_test1)

classification_report_gbr = classification_report(y_test1,y_pred_disorder)
f1_scoregbr = f1_score(y_test1,y_pred_disorder,average='macro')

print("GBR Model")
print(classification_report_gbr)
# Out:
# GBR Model
#               precision    recall  f1-score   support
#
#            0       0.89      0.86      0.88        29
#            1       0.93      0.96      0.94        52
#            2       0.96      0.94      0.95        51
#
#     accuracy                           0.93       132
#    macro avg       0.93      0.92      0.92       132
# weighted avg       0.93      0.93      0.93       132

# %%
model3.fit(X_train1,y_train1)
y_pred_disorder = model3.predict(X_test1)

classification_report_RF = classification_report(y_test1,y_pred_disorder)

print("RF Model")
print(classification_report_RF)
# Out:
# RF Model
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86        29
#            1       0.93      0.96      0.94        52
#            2       0.96      0.92      0.94        51
#
#     accuracy                           0.92       132
#    macro avg       0.92      0.92      0.92       132
# weighted avg       0.92      0.92      0.92       132

# %%
model5.fit(X_train1,y_train1)
y_pred_disorder = model5.predict(X_test1)

classification_report_XGBC = classification_report(y_test1,y_pred_disorder)

print("XGBC Model")
print(classification_report_XGBC)
# Out:
# XGBC Model
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86        29
#            1       0.91      0.96      0.93        52
#            2       0.98      0.92      0.95        51
#
#     accuracy                           0.92       132
#    macro avg       0.92      0.92      0.92       132
# weighted avg       0.93      0.92      0.92       132

# %%
model8.fit(X_train1,y_train1)
y_pred_disorder = model8.predict(X_test1)

classification_report_Ada = classification_report(y_test1,y_pred_disorder)

print("AdaBoost Model")
print(classification_report_Ada)
# Out:
# AdaBoost Model
#               precision    recall  f1-score   support
#
#            0       0.61      0.93      0.74        29
#            1       0.91      0.75      0.82        52
#            2       1.00      0.88      0.94        51
#
#     accuracy                           0.84       132
#    macro avg       0.84      0.85      0.83       132
# weighted avg       0.88      0.84      0.85       132
